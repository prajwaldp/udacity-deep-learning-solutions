# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception(
          'Failed to verify ' + filename + '. Can you get to it with a browser?')
    
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    
    for word, _ in count:
        dictionary[word] = len(dictionary)
    
    data = list()
    unk_count = 0
    
    for word in words:
    
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
    
        data.append(index)
  
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)

    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)

    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
    
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
    
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)

    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'anarchism', 'term', 'originated', 'term', 'as', 'originated', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                                                      stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases,
                                                     inputs=embed, labels=train_labels,
                                                     num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    
    tf.global_variables_initializer().run()
    
    print('Initialized')
    
    average_loss = 0
    
    for step in range(num_steps):
    
        batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_dataset: batch_data,
                     train_labels: batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000

          # The average loss is an estimate of the loss over the last 2000 batches.

            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0

        # note that this is expensive (~20% slowdown if computed every 500 steps)

        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.316727
# Nearest to if: extension, reginald, airways, manuals, bluebeard, baka, socioeconomic, qualifies,
# Nearest to had: infielders, liberties, flowers, nest, monsoon, casing, sinful, acls,
# Nearest to can: express, lifeforms, xanadu, scanners, charms, quartz, caviar, degeneracy,
# Nearest to but: revulsion, trappings, bunkers, dogmatically, rounders, melanesia, marley, looted,
# Nearest to more: similar, operates, amphibians, pacioli, tyndale, accordions, decode, expectations,
# Nearest to of: unschooling, sihanouk, thaw, boito, nonterminals, isps, hana, phonemes,
# Nearest to UNK: crichton, isadora, diners, gatsby, white, weighty, firsts, suite,
# Nearest to is: mosaics, swabia, privations, budo, mesogens, leap, operations, shemini,
# Nearest to many: friar, hanged, oldenburg, untranslated, srpska, nsync, jarrett, odi,
# Nearest to american: hugo, extradition, thoroughly, sipe, sonnet, booster, scourge, karsh,
# Nearest to after: ctbt, acf, pornography, presumptive, tobruk, accommodated, adored, isopropyl,
# Nearest to see: kazakhstani, wove, ola, lampoon, formalised, miata, nationalities, befitting,
# Nearest to which: rutger, amo, caucasian, advisable, symmes, solemn, heywood, farther,
# Nearest to are: satires, adds, definable, pebble, solace, zx, aggadah, mercantilists,
# Nearest to been: glycolytic, gulden, cannabis, srpska, clapping, beauties, lukashenko, hural,
# Nearest to such: svante, monster, slash, obliged, autodidacts, pendant, apoplexy, montane,
# Average loss at step 2000: 4.363776
# Average loss at step 4000: 3.865594
# Average loss at step 6000: 3.791414
# Average loss at step 8000: 3.693966
# Average loss at step 10000: 3.611551
# Nearest to if: reginald, patrician, poitou, rockefeller, oppenheim, manuals, solvable, bluebeard,
# Nearest to had: was, has, have, acls, seville, were, like, typically,
# Nearest to can: would, may, stray, woodcut, casinos, must, could, esperantists,
# Nearest to but: sequencers, and, could, elisabetta, are, heaviest, gearbox, showers,
# Nearest to more: similar, amphibians, decode, immoral, good, outsiders, pacioli, elusive,
# Nearest to of: in, for, commits, and, nagy, petitcodiac, follower, vie,
# Nearest to UNK: maclennan, isps, siouxsie, empowering, ribeira, language, al, timurid,
# Nearest to is: was, are, has, zur, became, be, virgins, were,
# Nearest to many: some, statistic, rh, hanged, srpska, untranslated, fiend, dijon,
# Nearest to american: sipe, karsh, and, distant, sucre, extradition, hearn, penitentiary,
# Nearest to after: during, publica, remarque, unbeaten, acf, estates, arcane, biopic,
# Nearest to see: kazakhstani, odin, progenitor, tambourine, messages, wove, lampoon, unesco,
# Nearest to which: also, that, it, rutger, who, this, mmorpg, winnipeg,
# Nearest to are: were, is, have, was, referencing, be, airplay, darwinism,
# Nearest to been: was, glycolytic, gms, srpska, cannabis, by, are, alfalfa,
# Nearest to such: well, itt, compensation, known, pedestrians, fraternities, blending, energized,
# Average loss at step 12000: 3.604069
# Average loss at step 14000: 3.569048
# Average loss at step 16000: 3.404903
# Average loss at step 18000: 3.460295
# Average loss at step 20000: 3.539526
# Nearest to if: but, reginald, could, when, rockefeller, think, poitou, solvable,
# Nearest to had: has, have, were, was, seville, having, wreckin, gerais,
# Nearest to can: may, would, will, must, could, should, to, might,
# Nearest to but: however, though, and, if, there, does, although, haydn,
# Nearest to more: less, similar, most, very, amphibians, decode, immoral, mammals,
# Nearest to of: for, in, nouveaux, altars, cartan, biruni, kurukshetra, at,
# Nearest to UNK: maclennan, cutlery, white, betrayed, parliamentary, patois, kes, decker,
# Nearest to is: was, are, has, were, became, be, zur, centrosomes,
# Nearest to many: some, these, other, several, all, such, most, statistic,
# Nearest to american: british, english, sipe, french, karsh, russian, archetypal, concoction,
# Nearest to after: from, during, acf, unbeaten, publica, estates, when, listeners,
# Nearest to see: odin, kolbe, tambourine, ritual, alt, kazakhstani, unesco, progenitor,
# Nearest to which: this, that, who, also, it, there, and, bowling,
# Nearest to are: were, is, have, sowell, really, previously, was, other,
# Nearest to been: become, be, were, fabien, alfalfa, srpska, was, reluctant,
# Nearest to such: well, known, these, many, itt, compensation, axon, pedestrians,
# Average loss at step 22000: 3.497667
# Average loss at step 24000: 3.486746
# Average loss at step 26000: 3.485664
# Average loss at step 28000: 3.481916
# Average loss at step 30000: 3.503350
# Nearest to if: when, could, where, however, think, experiential, but, cede,
# Nearest to had: has, have, was, were, having, when, seville, reluctant,
# Nearest to can: may, would, will, could, must, should, might, cannot,
# Nearest to but: however, and, though, although, that, reissues, which, sinners,
# Nearest to more: less, very, most, similar, ecotourism, amphibians, decode, immoral,
# Nearest to of: in, altars, petitcodiac, for, from, and, thaw, uomo,
# Nearest to UNK: clouds, achieve, swedish, taverns, usp, sensible, pompidou, maclennan,
# Nearest to is: was, has, are, be, does, became, were, had,
# Nearest to many: some, several, these, other, most, such, all, various,
# Nearest to american: british, english, indian, russian, archetypal, italian, canadian, sipe,
# Nearest to after: before, during, when, from, in, unbeaten, sprite, oahu,
# Nearest to see: odin, kolbe, incite, peloponnesian, salicylic, is, bova, unlike,
# Nearest to which: this, that, it, who, also, but, mmorpg, these,
# Nearest to are: were, is, have, include, be, these, previously, those,
# Nearest to been: become, already, was, be, reluctant, were, fabien, alfalfa,
# Nearest to such: well, known, these, many, some, axon, itt, vrije,
# Average loss at step 32000: 3.501935
# Average loss at step 34000: 3.496063
# Average loss at step 36000: 3.454125
# Average loss at step 38000: 3.302621
# Average loss at step 40000: 3.423497
# Nearest to if: when, where, could, think, nominal, cede, experiential, bowed,
# Nearest to had: has, have, was, were, successfully, since, been, galactica,
# Nearest to can: may, will, would, could, must, should, might, cannot,
# Nearest to but: however, though, and, although, which, where, while, that,
# Nearest to more: less, most, very, questions, longer, gases, similar, immoral,
# Nearest to of: altars, in, for, nouveaux, petitcodiac, from, with, same,
# Nearest to UNK: b, neglects, der, maclennan, flavour, van, aficionados, larkin,
# Nearest to is: was, has, be, are, unranked, citeseer, stanislav, cleanliness,
# Nearest to many: some, several, these, various, most, those, such, other,
# Nearest to american: british, english, indian, russian, canadian, helmholtz, french, rituals,
# Nearest to after: before, during, when, from, sprite, geared, while, menu,
# Nearest to see: odin, kolbe, can, but, progenitor, stoned, known, salicylic,
# Nearest to which: that, this, who, also, usually, it, but, what,
# Nearest to are: were, have, is, centrosomes, while, these, be, include,
# Nearest to been: become, already, was, fabien, be, reluctant, gone, alfalfa,
# Nearest to such: well, these, known, many, axon, itt, some, bowler,
# Average loss at step 42000: 3.434239
# Average loss at step 44000: 3.452538
# Average loss at step 46000: 3.452770
# Average loss at step 48000: 3.360685
# Average loss at step 50000: 3.385127
# Nearest to if: when, where, though, cede, could, think, although, nominal,
# Nearest to had: has, have, was, having, were, never, been, successfully,
# Nearest to can: may, could, would, will, must, should, might, cannot,
# Nearest to but: however, though, although, while, and, when, bigotry, which,
# Nearest to more: less, most, very, longer, too, questions, rh, amphibians,
# Nearest to of: including, in, and, altars, carbonyl, uomo, metasyntactic, epidemiological,
# Nearest to UNK: de, ehr, l, clouds, la, colorless, doesburg, vibrant,
# Nearest to is: was, has, are, although, be, does, guildhall, marsden,
# Nearest to many: some, several, these, various, other, both, most, those,
# Nearest to american: english, indian, british, french, russian, rituals, helmholtz, canadian,
# Nearest to after: before, during, when, while, calderas, geared, grilled, without,
# Nearest to see: odin, salicylic, ccitt, renouncing, give, progenitor, stefano, mussorgsky,
# Nearest to which: that, this, also, usually, often, who, where, webster,
# Nearest to are: were, is, have, these, those, be, being, targum,
# Nearest to been: become, be, fabien, already, reluctant, previously, was, gone,
# Nearest to such: well, these, known, many, elegy, itt, regarded, axon,
# Average loss at step 52000: 3.433576
# Average loss at step 54000: 3.425512
# Average loss at step 56000: 3.437965
# Average loss at step 58000: 3.394728
# Average loss at step 60000: 3.398325
# Nearest to if: when, though, where, before, since, although, cede, without,
# Nearest to had: has, have, was, were, having, successfully, never, did,
# Nearest to can: may, could, would, must, will, might, should, cannot,
# Nearest to but: however, although, though, and, while, than, when, hutu,
# Nearest to more: less, very, most, longer, too, other, waterman, smaller,
# Nearest to of: in, for, actual, same, including, workflow, altars, saya,
# Nearest to UNK: videogames, expatriate, pompidou, theravada, ssbauer, pron, topics, frication,
# Nearest to is: was, are, has, does, became, although, dimorphism, suggests,
# Nearest to many: some, several, these, various, all, most, other, such,
# Nearest to american: british, russian, english, french, indian, australian, helmholtz, european,
# Nearest to after: before, during, while, when, without, despite, surrounding, following,
# Nearest to see: list, but, odin, mussorgsky, include, stoned, renouncing, contains,
# Nearest to which: that, this, what, these, also, who, however, usually,
# Nearest to are: were, is, have, these, include, centrosomes, those, chrominance,
# Nearest to been: become, be, already, was, fabien, previously, reluctant, were,
# Nearest to such: known, well, many, these, itt, opposed, elegy, axon,
# Average loss at step 62000: 3.242881
# Average loss at step 64000: 3.251414
# Average loss at step 66000: 3.402524
# Average loss at step 68000: 3.393776
# Average loss at step 70000: 3.360564
# Nearest to if: when, though, where, before, because, without, cede, since,
# Nearest to had: has, have, was, were, successfully, having, never, ceded,
# Nearest to can: may, could, would, will, must, should, might, cannot,
# Nearest to but: however, though, while, although, which, and, that, bca,
# Nearest to more: less, most, very, too, longer, highly, ecotourism, smaller,
# Nearest to of: including, actual, in, physical, although, include, uomo, like,
# Nearest to UNK: et, wasteful, references, beauharnais, basileus, si, ln, peaking,
# Nearest to is: was, has, are, be, became, does, although, makes,
# Nearest to many: some, several, these, most, various, all, both, other,
# Nearest to american: british, english, french, russian, indian, helmholtz, rockall, professional,
# Nearest to after: before, during, while, when, though, despite, without, grilled,
# Nearest to see: mussorgsky, list, include, stoned, and, contains, references, odin,
# Nearest to which: that, this, also, but, what, these, however, usually,
# Nearest to are: were, is, have, these, include, although, while, centrosomes,
# Nearest to been: become, be, already, was, previously, fabien, were, gone,
# Nearest to such: these, well, known, many, opposed, austere, bowler, gage,
# Average loss at step 72000: 3.373698
# Average loss at step 74000: 3.348800
# Average loss at step 76000: 3.312737
# Average loss at step 78000: 3.350430
# Average loss at step 80000: 3.376221
# Nearest to if: when, though, before, where, since, although, think, cede,
# Nearest to had: has, have, was, were, having, successfully, never, began,
# Nearest to can: could, may, will, must, would, might, should, cannot,
# Nearest to but: however, although, though, while, and, than, which, vedic,
# Nearest to more: less, very, most, too, quite, danced, longer, rh,
# Nearest to of: altars, telstar, workflow, in, scrat, entire, including, actual,
# Nearest to UNK: typhus, dr, frisbee, wilson, burns, frasier, bigfoot, coach,
# Nearest to is: was, are, has, became, includes, were, be, although,
# Nearest to many: some, several, various, these, all, most, both, those,
# Nearest to american: british, french, russian, australian, septuagint, helmholtz, indian, italian,
# Nearest to after: before, during, when, despite, though, while, without, following,
# Nearest to see: dicots, but, repudiated, mussorgsky, list, stoned, known, parke,
# Nearest to which: that, this, also, usually, typically, what, these, often,
# Nearest to are: were, is, have, include, although, centrosomes, be, these,
# Nearest to been: become, be, already, gone, being, was, previously, recently,
# Nearest to such: these, well, known, opposed, including, follows, elegy, itt,
# Average loss at step 82000: 3.405683
# Average loss at step 84000: 3.411267
# Average loss at step 86000: 3.392264
# Average loss at step 88000: 3.352957
# Average loss at step 90000: 3.366159
# Nearest to if: where, when, since, though, although, did, before, think,
# Nearest to had: has, have, was, were, having, never, successfully, began,
# Nearest to can: could, may, must, will, would, might, should, cannot,
# Nearest to but: however, though, and, although, while, until, that, he,
# Nearest to more: less, very, most, too, highly, extremely, greater, quite,
# Nearest to of: including, uomo, actual, altars, include, metasyntactic, for, donegal,
# Nearest to UNK: dusseldorf, pei, ludwig, gimlin, pompidou, ac, sanderson, cameraman,
# Nearest to is: was, has, are, although, appears, be, does, were,
# Nearest to many: some, several, various, all, these, most, both, numerous,
# Nearest to american: british, french, russian, australian, indian, italian, european, german,
# Nearest to after: before, during, when, despite, while, without, though, loudest,
# Nearest to see: list, repudiated, dicots, kolbe, external, mchale, renouncing, references,
# Nearest to which: that, this, also, usually, what, who, often, but,
# Nearest to are: were, is, have, include, these, while, those, although,
# Nearest to been: become, be, already, previously, was, gone, being, fabien,
# Nearest to such: known, well, these, follows, regarded, certain, opposed, lordship,
# Average loss at step 92000: 3.401581
# Average loss at step 94000: 3.254931
# Average loss at step 96000: 3.359046
# Average loss at step 98000: 3.245843
# Average loss at step 100000: 3.362571
# Nearest to if: when, where, though, did, since, although, cede, so,
# Nearest to had: has, have, having, was, were, since, successfully, never,
# Nearest to can: could, may, must, would, will, should, might, cannot,
# Nearest to but: however, although, though, and, where, while, which, reissues,
# Nearest to more: less, most, very, too, greater, extremely, danced, highly,
# Nearest to of: in, including, weakest, metasyntactic, workflow, nouveaux, uomo, actual,
# Nearest to UNK: http, giantess, gen, et, maclennan, delian, bigfoot, uptake,
# Nearest to is: was, has, became, are, be, refers, courting, appears,
# Nearest to many: some, several, various, all, these, those, numerous, few,
# Nearest to american: british, french, russian, australian, canadian, indian, explication, italian,
# Nearest to after: before, during, when, despite, without, loudest, while, until,
# Nearest to see: references, parke, external, renouncing, dicots, list, tms, mee,
# Nearest to which: that, this, usually, what, typically, who, however, but,
# Nearest to are: were, have, is, these, although, include, those, including,
# Nearest to been: become, be, already, recently, gone, was, previously, alfalfa,
# Nearest to such: known, well, these, follows, separate, opposed, many, certain,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')

    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# In the Continuous Bag of Words model, the context in the input and the word is the output (vice versa in the skip-gram model).

# %%
data_index = 0

def generate_batch(batch_size, skip_window):
    global data_index
    
    span = 2 * skip_window + 1 # len(skip_window) words on either side
    
    batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    
    buffer = collections.deque(maxlen=span)

    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)

    for i in range(batch_size):
        
        buffer_list = list(buffer)
        labels[i, 0] = buffer_list.pop(skip_window)
        batch[i] = buffer_list
        
        
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)

    return batch, labels


print('data:', [reverse_dictionary[di] for di in data[:8]])

for skip_window in [1, 3]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, skip_window=skip_window)

    print('\nwith skip_window = %d:' % skip_window)
    print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with skip_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first'], ['abuse', 'used'], ['first', 'against']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with skip_window = 3:
#     batch: [['anarchism', 'originated', 'as', 'term', 'of', 'abuse'], ['originated', 'as', 'a', 'of', 'abuse', 'first'], ['as', 'a', 'term', 'abuse', 'first', 'used'], ['a', 'term', 'of', 'first', 'used', 'against'], ['term', 'of', 'abuse', 'used', 'against', 'early'], ['of', 'abuse', 'first', 'against', 'early', 'working'], ['abuse', 'first', 'used', 'early', 'working', 'class'], ['first', 'used', 'against', 'working', 'class', 'radicals']]
#     labels: ['a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early']

# %%
batch_size = 128
embedding_size = 128
skip_window = 1

valid_size = 16
valid_window = 100
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, skip_window * 2])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                                                      stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases,
                                                     inputs=tf.reduce_sum(embed, 1), labels=train_labels,
                                                     num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    
    tf.global_variables_initializer().run()
    
    print('Initialized')
    
    average_loss = 0
    
    for step in range(num_steps):
    
        batch_data, batch_labels = generate_batch(batch_size, skip_window)
        feed_dict = {train_dataset: batch_data,
                     train_labels: batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000

          # The average loss is an estimate of the loss over the last 2000 batches.

            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0

        # note that this is expensive (~20% slowdown if computed every 500 steps)

        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.790323
# Nearest to of: harmonics, sejanus, harmful, vanishing, comfortable, curve, pulaski, hyatt,
# Nearest to one: chimp, ghana, designation, graduate, lambasted, frivolous, rtiges, simply,
# Nearest to would: hinduism, holley, schiff, kambojas, isu, bone, steed, magical,
# Nearest to than: xviii, vet, ilinden, satiric, housman, disseminate, wr, agency,
# Nearest to not: estimation, contradictions, meiji, crackers, goaltender, leland, andechs, prentice,
# Nearest to to: cyan, trapdoor, mps, hein, germline, jutes, creep, he,
# Nearest to this: interviewer, turin, commodity, bloodshed, hawker, arexx, camping, taklamakan,
# Nearest to such: insulating, montoneros, oceans, billing, conceptually, behaviorist, dana, vibration,
# Nearest to world: adt, brightest, oratio, sewer, oed, scripts, montana, ought,
# Nearest to while: ballparks, balderus, affix, allyn, pacification, yusuf, bubba, passive,
# Nearest to on: hourly, staffordshire, jacobins, cooker, reborn, spaceflights, festivities, rambling,
# Nearest to state: inadequate, dhea, battuta, felling, laborers, silver, hormonal, families,
# Nearest to seven: domini, stromata, disobeyed, restructuring, jakarta, suburb, legalized, melvins,
# Nearest to when: hillside, haran, hemorrhage, berthold, wanderings, carla, penzias, huike,
# Nearest to as: spiritus, arrange, fluorite, icrm, dialogues, closest, generalisation, ernie,
# Nearest to three: arch, heated, reusable, loudspeaker, tv, sensible, nafta, debut,
# Average loss at step 2000: 4.109711
# Average loss at step 4000: 3.560015
# Average loss at step 6000: 3.387033
# Average loss at step 8000: 3.239961
# Average loss at step 10000: 3.176066
# Nearest to of: vanishing, jasmuheen, carnivora, akron, yy, in, harmonics, ffffff,
# Nearest to one: two, eight, four, three, seven, six, five, nine,
# Nearest to would: may, can, will, should, could, must, cannot, might,
# Nearest to than: or, tab, housman, dreamt, wr, bowles, gilchrist, highway,
# Nearest to not: usually, also, electrons, never, it, perry, distinctly, we,
# Nearest to to: mps, would, malm, will, could, deo, can, jutes,
# Nearest to this: it, which, the, his, what, explodes, their, synods,
# Nearest to such: billing, well, antonius, purifying, insulating, changeover, microphone, eaten,
# Nearest to world: vietnam, mycenaean, weighs, magnetite, urea, montana, imine, bsa,
# Nearest to while: where, ballparks, pants, vogel, balderus, nada, for, torment,
# Nearest to on: in, upon, reborn, melody, at, complexion, irrevocably, hosted,
# Nearest to state: hormonal, liturgy, facilitating, hutton, dhea, emission, pranksters, nutrients,
# Nearest to seven: six, nine, eight, five, four, three, zero, two,
# Nearest to when: impressionists, spitting, where, postpositions, during, studd, hermitian, haran,
# Nearest to as: ferrous, tius, manichean, princip, within, nautilus, misquoted, dorothea,
# Nearest to three: four, six, five, two, seven, eight, zero, nine,
# Average loss at step 12000: 3.202658
# Average loss at step 14000: 3.153537
# Average loss at step 16000: 3.172384
# Average loss at step 18000: 3.129478
# Average loss at step 20000: 2.983671
# Nearest to of: carnivora, lorentz, in, shorthand, specialty, for, markov, renders,
# Nearest to one: two, six, seven, eight, four, five, three, paton,
# Nearest to would: will, can, may, could, should, must, might, cannot,
# Nearest to than: or, tab, highway, liberian, habitual, symbolist, wr, olympian,
# Nearest to not: never, usually, officially, still, clung, also, deuterocanonical, electrons,
# Nearest to to: mps, elf, nei, might, will, would, could, amir,
# Nearest to this: which, it, the, what, that, explodes, some, reneged,
# Nearest to such: these, well, many, known, antonius, eaten, petition, billing,
# Nearest to world: vietnam, impassioned, winged, aberdeenshire, airy, hornby, commonwealth, bsa,
# Nearest to while: where, when, outburst, after, and, analects, pants, einsatzgruppen,
# Nearest to on: upon, reborn, in, at, sidearm, hosted, irrevocably, circulating,
# Nearest to state: states, liturgy, dhea, caen, pranksters, hormonal, emission, cunha,
# Nearest to seven: six, five, four, eight, nine, three, zero, two,
# Nearest to when: if, before, after, where, while, hermitian, spitting, although,
# Nearest to as: manichean, reopening, mpr, dorothea, recur, ferrous, moderating, sala,
# Nearest to three: four, six, five, seven, two, eight, nine, zero,
# Average loss at step 22000: 3.073757
# Average loss at step 24000: 3.036991
# Average loss at step 26000: 3.007089
# Average loss at step 28000: 3.027816
# Average loss at step 30000: 3.004259
# Nearest to of: in, carnivora, mentats, including, grosbeak, textual, lorentz, vanishing,
# Nearest to one: two, three, four, five, six, seven, elmore, vn,
# Nearest to would: will, could, may, can, must, might, should, cannot,
# Nearest to than: or, habitual, far, much, glaze, and, but, southerner,
# Nearest to not: usually, still, never, officially, decidedly, now, deuterocanonical, perry,
# Nearest to to: would, can, must, could, will, should, might, may,
# Nearest to this: which, it, what, that, the, emigrants, mime, reneged,
# Nearest to such: well, these, known, many, certain, eaten, regarded, antonius,
# Nearest to world: vietnam, airy, preserve, impassioned, bsa, isabelle, louvre, aberdeenshire,
# Nearest to while: when, after, although, though, before, analects, bolshevism, where,
# Nearest to on: upon, reborn, irrevocably, sidearm, in, at, besides, hosted,
# Nearest to state: states, government, kendall, hutton, city, daemon, yeo, liturgy,
# Nearest to seven: nine, six, four, eight, five, three, zero, two,
# Nearest to when: if, while, before, after, although, where, during, because,
# Nearest to as: manichean, princip, retrofitted, ferrous, brains, dorothea, delphinus, tags,
# Nearest to three: five, four, six, two, seven, eight, nine, one,
# Average loss at step 32000: 2.828658
# Average loss at step 34000: 2.954233
# Average loss at step 36000: 2.945395
# Average loss at step 38000: 2.940788
# Average loss at step 40000: 2.931434
# Nearest to of: carnivora, although, shorthand, yy, including, bringer, troglodytes, academically,
# Nearest to one: two, seven, six, five, three, revolutionized, novello, ananda,
# Nearest to would: could, will, can, may, should, might, must, cannot,
# Nearest to than: far, much, but, glaze, or, races, habitual, and,
# Nearest to not: usually, still, never, almost, pacifist, generally, always, negligent,
# Nearest to to: catechetical, will, malm, must, should, can, amir, would,
# Nearest to this: which, it, what, the, aaa, maglev, another, aalborg,
# Nearest to such: well, these, regarded, themselves, certain, known, including, opposed,
# Nearest to world: brightest, impassioned, hornby, adt, vietnam, pdp, designing, airy,
# Nearest to while: when, although, during, after, and, habitual, though, before,
# Nearest to on: upon, reborn, through, sidearm, warranted, under, hosted, during,
# Nearest to state: city, government, cubans, kilobytes, cunha, kendall, uploads, hutton,
# Nearest to seven: eight, five, four, six, nine, three, zero, two,
# Nearest to when: if, before, after, while, during, although, though, because,
# Nearest to as: manichean, oval, tansley, superficially, summoned, moderating, icrm, cooperated,
# Nearest to three: five, six, four, seven, two, eight, zero, nine,
# Average loss at step 42000: 2.951210
# Average loss at step 44000: 2.957410
# Average loss at step 46000: 2.910195
# Average loss at step 48000: 2.862845
# Average loss at step 50000: 2.848910
# Nearest to of: including, during, serialism, grosbeak, simplest, in, although, invents,
# Nearest to one: two, seven, six, four, three, eight, nine, elmore,
# Nearest to would: could, will, may, might, should, can, must, cannot,
# Nearest to than: or, much, far, races, womb, archipelago, but, liberian,
# Nearest to not: still, almost, always, never, generally, usually, actually, deuterocanonical,
# Nearest to to: must, will, could, amir, malm, should, would, might,
# Nearest to this: it, which, what, reneged, he, monsignor, nativist, loo,
# Nearest to such: well, known, these, certain, opposed, regarded, many, follows,
# Nearest to world: impassioned, brightest, pdp, drm, vegetative, airy, bsa, louvre,
# Nearest to while: although, when, during, before, after, and, though, were,
# Nearest to on: upon, reborn, in, under, through, sidearm, at, circulating,
# Nearest to state: city, states, cubans, yeo, government, merleau, hutton, kendall,
# Nearest to seven: eight, nine, six, four, five, three, zero, two,
# Nearest to when: if, before, while, after, where, during, although, because,
# Nearest to as: oval, manichean, dorothea, moderating, recur, tius, burrow, lifeless,
# Nearest to three: four, five, two, six, eight, seven, nine, zero,
# Average loss at step 52000: 2.888778
# Average loss at step 54000: 2.860516
# Average loss at step 56000: 2.859446
# Average loss at step 58000: 2.752851
# Average loss at step 60000: 2.828757
# Nearest to of: although, academically, carnivora, in, jasmuheen, elder, lorentz, keyes,
# Nearest to one: two, six, four, three, seven, five, eight, nine,
# Nearest to would: could, will, can, might, should, must, may, cannot,
# Nearest to than: or, but, womb, liberian, far, aether, propagation, races,
# Nearest to not: never, actually, still, always, usually, now, almost, generally,
# Nearest to to: must, should, could, would, deo, malm, martialed, towards,
# Nearest to this: it, which, the, what, any, diab, aaa, ezek,
# Nearest to such: these, opposed, well, known, certain, follows, regarded, those,
# Nearest to world: impassioned, vegetative, brightest, oldest, nation, country, airy, urea,
# Nearest to while: although, when, however, before, though, after, saw, bolshevism,
# Nearest to on: upon, in, through, reborn, sidearm, at, under, within,
# Nearest to state: states, liturgy, city, kendall, government, federal, cubans, sluggish,
# Nearest to seven: six, eight, five, four, nine, three, zero, two,
# Nearest to when: if, before, after, during, where, while, although, though,
# Nearest to as: manichean, recur, comfortable, oval, because, dorothea, bodywork, moderating,
# Nearest to three: four, six, two, five, seven, eight, nine, zero,
# Average loss at step 62000: 2.833250
# Average loss at step 64000: 2.772640
# Average loss at step 66000: 2.761353
# Average loss at step 68000: 2.710876
# Average loss at step 70000: 2.785070
# Nearest to of: serialism, in, interwar, prosciutto, including, shorthand, functionalists, grosbeak,
# Nearest to one: two, three, seven, six, four, five, eight, nine,
# Nearest to would: could, will, might, should, must, may, can, cannot,
# Nearest to than: or, liberian, much, propagation, womb, enact, schiff, xviii,
# Nearest to not: never, always, actually, now, usually, almost, still, generally,
# Nearest to to: would, will, must, could, nx, can, should, catechetical,
# Nearest to this: which, it, what, the, any, grozny, some, phanerozoic,
# Nearest to such: known, opposed, well, themselves, described, follows, these, certain,
# Nearest to world: impassioned, ramanujan, vietnam, hornby, fatigue, louvre, championship, nation,
# Nearest to while: although, when, before, after, though, however, including, conservationist,
# Nearest to on: upon, in, under, within, sidearm, around, through, at,
# Nearest to state: states, kendall, government, liturgy, city, uploads, yeo, federal,
# Nearest to seven: eight, five, six, nine, four, three, zero, two,
# Nearest to when: if, before, after, although, while, where, though, during,
# Nearest to as: oval, recur, dorothea, manichean, householder, moderating, qadhafi, mechanically,
# Nearest to three: six, five, four, seven, two, eight, nine, zero,
# Average loss at step 72000: 2.798618
# Average loss at step 74000: 2.646046
# Average loss at step 76000: 2.803189
# Average loss at step 78000: 2.824352
# Average loss at step 80000: 2.778487
# Nearest to of: serialism, textual, kongsberg, in, lorentz, and, interwar, carnivora,
# Nearest to one: two, three, four, seven, six, eight, five, iole,
# Nearest to would: could, will, might, can, should, must, may, cannot,
# Nearest to than: or, much, propagation, liberian, womb, carriage, enact, maximizing,
# Nearest to not: almost, actually, always, never, still, generally, usually, typically,
# Nearest to to: malm, moncada, will, would, cannot, should, deo, nx,
# Nearest to this: which, it, what, mime, that, some, the, another,
# Nearest to such: well, known, these, opposed, certain, themselves, follows, described,
# Nearest to world: impassioned, drm, vietnam, hornby, brightest, economy, development, u,
# Nearest to while: although, when, though, before, after, including, however, resulting,
# Nearest to on: upon, in, sidearm, through, reborn, around, during, under,
# Nearest to state: states, city, liturgy, federal, kendall, protesters, fund, national,
# Nearest to seven: six, eight, five, nine, four, three, zero, two,
# Nearest to when: if, before, although, after, though, while, where, during,
# Nearest to as: oval, manichean, recur, silas, canossa, householder, dorothea, slant,
# Nearest to three: four, five, six, two, seven, eight, zero, nine,
# Average loss at step 82000: 2.665564
# Average loss at step 84000: 2.770408
# Average loss at step 86000: 2.731054
# Average loss at step 88000: 2.750578
# Average loss at step 90000: 2.736242
# Nearest to of: including, lorentz, for, despite, amplifies, carnivora, troglodytes, containing,
# Nearest to one: two, four, six, eight, seven, three, clog, wicket,
# Nearest to would: could, will, might, can, should, must, may, cannot,
# Nearest to than: or, propagation, liberian, much, southerner, even, womb, goodbye,
# Nearest to not: never, always, actually, now, almost, still, generally, typically,
# Nearest to to: would, must, can, should, could, might, cannot, helped,
# Nearest to this: which, it, what, another, loo, mime, some, the,
# Nearest to such: well, known, themselves, these, follows, certain, opposed, described,
# Nearest to world: impassioned, development, drm, hornby, vietnam, louvre, disseminated, rolfe,
# Nearest to while: although, though, when, whilst, before, after, or, however,
# Nearest to on: upon, in, through, reborn, near, within, circulating, via,
# Nearest to state: states, city, national, fund, government, liturgy, federal, hetfield,
# Nearest to seven: six, eight, nine, four, five, three, zero, two,
# Nearest to when: if, while, although, before, where, though, after, during,
# Nearest to as: recur, including, oval, mls, moderating, delphinus, send, like,
# Nearest to three: four, six, five, two, seven, eight, nine, zero,
# Average loss at step 92000: 2.677676
# Average loss at step 94000: 2.719964
# Average loss at step 96000: 2.702104
# Average loss at step 98000: 2.367154
# Average loss at step 100000: 2.405089
# Nearest to of: amplifies, in, despite, invents, bringer, troglodytes, pickard, from,
# Nearest to one: two, three, six, four, seven, five, vn, revolutionized,
# Nearest to would: could, will, might, should, can, must, cannot, may,
# Nearest to than: or, propagation, slightly, liberian, southerner, much, scenario, archipelago,
# Nearest to not: never, always, indeed, now, actually, still, you, usually,
# Nearest to to: will, must, would, should, malm, amir, cannot, could,
# Nearest to this: which, some, it, another, the, what, nostratic, his,
# Nearest to such: well, these, known, certain, opposed, themselves, many, serve,
# Nearest to world: impassioned, hornby, drm, novel, louvre, isabelle, bsa, ppp,
# Nearest to while: although, though, when, whilst, before, but, began, after,
# Nearest to on: upon, reborn, near, through, in, absurdity, around, sidearm,
# Nearest to state: states, government, national, city, liturgy, federal, company, house,
# Nearest to seven: six, eight, five, four, nine, three, zero, two,
# Nearest to when: if, while, before, after, though, although, where, during,
# Nearest to as: recur, moderating, manichean, dorothea, comfortable, oval, qadhafi, bayonet,
# Nearest to three: four, five, six, seven, eight, two, nine, zero,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')

    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
